# %% [markdown]
# <a href="https://colab.research.google.com/github/Gnanapriya177/Landcover_Classification/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
from torchvision.datasets import EuroSAT
from torchvision import transforms
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt

print(torch.__version__)
print(torchvision.__version__)

transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
])

dataset = EuroSAT(root='./data', download=True, transform=transform)

class_names = dataset.classes
print("Classes:", class_names)
print("Total images:", len(dataset))
# Out:
# 2.11.0+cu128
# 0.26.0+cu128
# 100%|██████████| 94.3M/94.3M [00:00<00:00, 106MB/s]
# Classes: ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']
# Total images: 27000

# %%
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

print("Train size:", len(train_dataset))
print("Val size:", len(val_dataset))
# Out:
# Train size: 21600
# Val size: 5400

# %%
import torch.nn as nn
from torchvision.models import resnet18, ResNet18_Weights

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

model = resnet18(weights=ResNet18_Weights.DEFAULT)

for param in model.parameters():
    param.requires_grad = False

num_classes = len(class_names)
model.fc = nn.Linear(model.fc.in_features, num_classes)

model = model.to(device)
print(model.fc)
# Out:
# Using device: cuda
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 161MB/s]
# Linear(in_features=512, out_features=10, bias=True)

# %%
criterion = nn.CrossEntropyLoss()

# Unfreeze the last block of ResNet18
for param in model.layer4.parameters():
    param.requires_grad = True

# Update optimizer to include these new trainable params
optimizer = torch.optim.Adam(
    list(model.fc.parameters()) + list(model.layer4.parameters()),
    lr=0.0001  # smaller LR since we're fine-tuning pretrained weights
)

# %%
num_epochs = 15

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_acc = 100 * correct / total
    print(f"Epoch {epoch+1}/{num_epochs} - Loss: {running_loss/len(train_loader):.4f} - Train Accuracy: {train_acc:.2f}%")
# Out:
# Epoch 1/15 - Loss: 0.3979 - Train Accuracy: 86.69%
# Epoch 2/15 - Loss: 0.1459 - Train Accuracy: 95.01%
# Epoch 3/15 - Loss: 0.0814 - Train Accuracy: 97.27%
# Epoch 4/15 - Loss: 0.0621 - Train Accuracy: 97.95%
# Epoch 5/15 - Loss: 0.0443 - Train Accuracy: 98.54%
# Epoch 6/15 - Loss: 0.0401 - Train Accuracy: 98.68%
# Epoch 7/15 - Loss: 0.0349 - Train Accuracy: 98.81%
# Epoch 8/15 - Loss: 0.0332 - Train Accuracy: 98.88%
# Epoch 9/15 - Loss: 0.0282 - Train Accuracy: 99.03%
# Epoch 10/15 - Loss: 0.0275 - Train Accuracy: 99.19%
# Epoch 11/15 - Loss: 0.0243 - Train Accuracy: 99.20%
# Epoch 12/15 - Loss: 0.0226 - Train Accuracy: 99.24%
# Epoch 13/15 - Loss: 0.0231 - Train Accuracy: 99.26%
# Epoch 14/15 - Loss: 0.0207 - Train Accuracy: 99.31%
# Epoch 15/15 - Loss: 0.0192 - Train Accuracy: 99.34%

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

print(classification_report(all_labels, all_preds, target_names=class_names))

cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Land Cover Classification')
plt.show()
# Out:
#                       precision    recall  f1-score   support
#
#           AnnualCrop       0.94      0.96      0.95       634
#               Forest       0.95      0.98      0.97       615
# HerbaceousVegetation       0.94      0.93      0.93       604
#              Highway       0.92      0.88      0.90       505
#           Industrial       0.98      0.97      0.98       486
#              Pasture       0.91      0.91      0.91       381
#        PermanentCrop       0.88      0.90      0.89       508
#          Residential       0.98      0.99      0.99       584
#                River       0.94      0.92      0.93       486
#              SeaLake       0.99      0.99      0.99       597
#
#             accuracy                           0.95      5400
#            macro avg       0.95      0.94      0.94      5400
#         weighted avg       0.95      0.95      0.95      5400
